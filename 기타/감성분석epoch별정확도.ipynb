# %% [markdown]
# ## 감성분석 epoch별 정확도 시각화

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./data/감성분석.csv', sep='\t')

# %%
data = data.set_index('epoch')

# %%
data
# Out:
#        train   test
# epoch
# 1      0.114  0.244
# 2      0.318  0.418
# 3      0.461  0.507
# 4      0.571  0.549
# 5      0.664  0.578
# 6      0.734  0.576
# 7      0.794  0.586
# 8      0.835  0.586
# 9      0.868  0.593
# 10     0.900  0.591
# 11     0.915  0.593
# 12     0.931  0.582
# 13     0.945  0.586
# 14     0.954  0.590
# 15     0.962  0.591
# 16     0.966  0.597
# 17     0.975  0.597
# 18     0.977  0.594
# 19     0.981  0.599
# 20     0.985  0.598
# 21     0.989  0.594
# 22     0.992  0.600
# 23     0.993  0.604
# 24     0.995  0.602
# 25     0.996  0.603
# 26     0.997  0.605
# 27     0.997  0.605
# 28     0.997  0.606
# 29     0.997  0.606
# 30     0.998  0.606

# %%
plt.plot(data)
plt.xlabel('epoch')
plt.ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')
